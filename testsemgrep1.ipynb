# %%
def greet(name):
    # insecure: using f-string with untrusted input (hypothetical rule trigger)
    print(f"Hello {name}!")

if __name__ == "__main__":
    user = input("Enter your name: ")
    greet(user)
# Out:
# Enter your name: Siri
# Hello Siri!
